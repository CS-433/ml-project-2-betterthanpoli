# %%
#!pip install bertopic
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-e08def8b8950> in <cell line: 12>()
#      10 import spacy
#      11 from spacy.lang.en.stop_words import STOP_WORDS
# ---> 12 from bertopic import BERTopic
#      13 import json
#      14 import pandas as pd
#
# ModuleNotFoundError: No module named 'bertopic'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install bertopic
from bertopic import BERTopic
import json
import pandas as pd

# %%
df = pd.DataFrame(pd.read_csv("drive/MyDrive/MLProject2/comments_long.csv"))
vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
X = vectorizer.fit_transform(df['Comments'])

# %%
n_topics = 20  # You can adjust the number of topics based on your data
lda = LatentDirichletAllocation(n_components=n_topics, max_iter=5,
                                learning_method='online', learning_offset=50.,
                                random_state=0)

lda.fit(X)
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic #{topic_idx + 1}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))
        print()

n_top_words = 10  # You can adjust the number of top words per topic
print_top_words(lda, vectorizer.get_feature_names_out(), n_top_words)
# Out:
# Topic #1:
# ft sq need type space texas indoor buildings exactly don
#
# Topic #2:
# thank check emissions footprint carbon bigger contractor ng said nc
#
# Topic #3:
# splits florida money ago mini stuff minus long plenty sure
#
# Topic #4:
# neighbors news country hydro make power needed coal battery outages
#
# Topic #5:
# opinion excellent piece heard got yes look just article nuclear
#
# Topic #6:
# interesting vs wrong built comment handle air price won love
#
# Topic #7:
# problem solve installing years 14 month subsidies year 300 deep
#
# Topic #8:
# thinking solution sold model late sorry filled storage entire room
#
# Topic #9:
# waste things believe improved mentioned utilities usually air article clean
#
# Topic #10:
# article read progress like works state concern buy california turned
#
# Topic #11:
# reduction grid infrastructure won roof national org monthly environmental maintenance
#
# Topic #12:
# big person installation learn wait story typical costs tell yes
#
# Topic #13:
# dual bit unit states defrost homes outside mode gas short
#
# Topic #14:
# oh called little try need nice thanks clean www buying
#
# Topic #15:
# sized properly absolutely correct second 60 paid result hear reach
#
# Topic #16:
# brand installers experience variable using quality happens degrees 30 heat
#
# Topic #17:
# thanks tax credit bad amazing live idea working model great
#
# Topic #18:
# based heat ground pump water temps single air weeks ones
#
# Topic #19:
# norway given popular winter time things work small toasty needs
#
# Topic #20:
# heat pump pumps gas house electricity air electric cold power

# %% [markdown]
# # Markdown

# %%
l = list(df["Comments"])
nlp = spacy.load("en_core_web_sm")

def remove_stopwords_from_sentences(sentences):
    # Process each sentence in the list using spaCy and remove stop words
    result = []
    for sentence in sentences:
        doc = nlp(sentence.lower())
        filtered_tokens = [token.text for token in doc if token.text not in STOP_WORDS]
        result.append(' '.join(filtered_tokens))

    return result

l = remove_stopwords_from_sentences(l)

# Display the original and modified sentences
# for original, modified in zip(l[0:10], result_sentences):
    #print("Original:", original)
    #print("Modified:", modified)
    #print()

# %%
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2", min_topic_size = 30)
topics, probs = topic_model.fit_transform(l)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
topic_model.get_topic(topic=3)
# Out:
# [('tax', 0.11273447720544418),
#  ('credit', 0.05541386064507778),
#  ('tax credit', 0.051778316345982255),
#  ('rebates', 0.04861543913206508),
#  ('credits', 0.04602517008531756),
#  ('income', 0.03934172113586226),
#  ('tax credits', 0.03618053727114982),
#  ('inflation reduction', 0.0348224645246256),
#  ('reduction act', 0.0348224645246256),
#  ('inflation', 0.0332952837078165)]

# %%
def get_original_comment(modified_comment):
  return df["Comments"][l.index(modified_comment)]

get_original_comment(topic_model.get_representative_docs(6)[0])
# Out:
# "I live in the UK. We installed a heat pump about 1 month ago. We also took advantage of the UK government's 5k grant, bringing the cost down to 7k. For the most part we've been happy. There were, however, snags and issues with the installation. This was mainly caused by the fact that more people WANT heat pumps than there are qualified installers (hint to young people looking for a career) and the installers thought they knew more than the install designer and installed things the way THEY THOUGHT it should be done and NOT according to the plan. It's all been sorted (for the most part) and some knuckles have been sharply slapped. I'm a uni prof and I know how 20 somethings think they know more than the person with 30+ years so I wasn't 'shocked' at the corner cutting. We have a meter that displays the cost per day and we're already in the 'plus' area."

# %%
df_topics = pd.DataFrame({'topic': topics, 'document': df["Comments"]})
df_topics.loc[df_topics["topic"] == 4]
# Out:
#       topic                                           document
# 24        4     If the power was off how did your furnace run?
# 34        4  I have to use a CPAP at night, and the city in...
# 39        4  I have a gas furnace, my state does a lot of f...
# 40        4  At least nuclear power doesn’t release CO2, an...
# 42        4  That's a really big generator. Would probably ...
# ...     ...                                                ...
# 2947      4  Wood might be renewable but it is a significan...
# 2951      4  Battery backup for a PV system is very expensi...
# 2952      4  That’s a perfectly reasonable route. I don’t h...
# 2953      4  Think wood burning stove. Or a back up generator.
# 2954      4  You mean like a fireplace or a Franklin stove?...
#
# [143 rows x 2 columns]

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="84bb5f8d-1cb3-4c94-b9b3-39544e65aa85" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84bb5f8d-1cb3-4c94-b9b3-39544e65aa85")) {                    Plotly.newPlot(                        "84bb5f8d-1cb3-4c94-b9b3-39544e65aa85",                        [{"customdata":[[0,"grid | fossil | power | solar | electricity",411],[1,"heat | pumps | heat pumps | pump | heat pump",280],[2,"article | people | like | technology | years",217],[3,"heat | heat pump | pump | electric | gas",150],[4,"gas | generator | power | wood | electricity",143],[5,"geothermal | ground | heat | geothermal heat | source",100],[6,"heat | pump | heat pump | pumps | heat pumps",88],[7,"heat | efficient | energy | efficiency | percent",87],[8,"air | heat | refrigerant | temperature | outside",75],[9,"insulation | homes | walls | insulated | home",74],[10,"mini | radiators | split | mini split | splits",70],[11,"tax | credit | tax credit | rebates | credits",37]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[411,280,217,150,143,100,88,87,75,74,70,37],"sizemode":"area","sizeref":0.256875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[13.170682907104492,-8.423996925354004,12.856369972229004,-6.813696384429932,12.913986206054688,-6.490805625915527,-7.77733850479126,-6.83876895904541,-8.603816032409668,-6.059170722961426,-7.607244968414307,13.578479766845703],"xaxis":"x","y":[9.943685531616211,-1.4986746311187744,10.20274543762207,-2.1729042530059814,9.44679069519043,-2.3368818759918213,-1.9411898851394653,-1.711728572845459,-1.037614107131958,-1.4568798542022705,-1.4491959810256958,9.546136856079102],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0, ...

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="aa11b420-05b3-44ab-8bba-003b85cd2738" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa11b420-05b3-44ab-8bba-003b85cd2738")) {                    Plotly.newPlot(                        "aa11b420-05b3-44ab-8bba-003b85cd2738",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.025620855531605886,0.025814298375902132,0.026346199480001185,0.028200498505700465,0.028241326831975132],"y":["electricity  ","solar  ","power  ","fossil  ","grid  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.028007763253215256,0.029156815623899827,0.032389492044346956,0.03244214604937388,0.04870760703483095],"y":["heat pump  ","pump  ","heat pumps  ","pumps  ","heat  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.02180248896510269,0.023954540500671383,0.024342504458514724,0.025405946629237546,0.03316790420239882],"y":["years  ","technology  ","like  ","people  ","article  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.020132641125512427,0.026022387224849428,0.031591179292601954,0.03197439054999103,0.03491741235523458],"y":["gas  ","electric  ","pump  ","heat pump  ","heat  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.029686119442922394,0.036988235655877645,0.04352860448384255,0.043546023337435666,0.05294137319067973],"y":["electricity  ","wood  ","power  ","generator  ","gas  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.03440959250435205,0.039434195046717274,0.04005952656437977,0.060113636219549134,0.0708590855256585],"y":["source  ","geothermal heat  ","heat  ","ground  ","geothermal  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.0498591786038333,0.05167664249538919,0.05856042940025965,0.06085087763025653,0.07408308890515788],"y":["heat pumps  ","pumps  ","heat pump  ","pump  ","heat  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.027964944078872168,0.04472921461377003,0.04652299896987347,0.04659397758229493,0.05491436734352057],"y":["percent  ","efficiency  ","energy  ","efficient  ","heat  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333 ...
